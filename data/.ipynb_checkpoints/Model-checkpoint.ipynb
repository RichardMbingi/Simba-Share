# %%
from alpha_vantage.timeseries import TimeSeries
import matplotlib.pyplot as plt
ts = TimeSeries(key='43OX7U3GKG0BJG8Y',output_format='pandas')
data, meta_data = ts.get_intraday(symbol='TSE:TD',interval='1min', outputsize='full')
print(data)
data['4. close'].plot()
plt.title('Intraday TimeSeries Google')
plt.show()
# Out:
#                      1. open  2. high  3. low  4. close  5. volume
# date
# 2019-10-17 11:36:00    73.83    73.85   73.80     73.83    21950.0
# 2019-10-17 11:35:00    73.84    73.86   73.83     73.83     3064.0
# 2019-10-17 11:34:00    73.84    73.84   73.83     73.83     1414.0
# 2019-10-17 11:33:00    73.87    73.87   73.81     73.84    16522.0
# 2019-10-17 11:32:00    73.88    73.88   73.88     73.88     9092.0
# ...                      ...      ...     ...       ...        ...
# 2019-10-10 09:35:00    72.99    73.02   72.96     73.02     6967.0
# 2019-10-10 09:34:00    73.02    73.07   72.94     72.99    15770.0
# 2019-10-10 09:33:00    72.96    73.00   72.94     73.00    10085.0
# 2019-10-10 09:32:00    72.83    73.00   72.83     72.95    15813.0
# 2019-10-10 09:31:00    72.83    72.83   72.83     72.83        0.0
#
# [1670 rows x 5 columns]

# %%
ts = TimeSeries(key='43OX7U3GKG0BJG8Y') #JSON
ts = TimeSeries(key='43OX7U3GKG0BJG8Y',output_format='pandas') #pandas
ts = TimeSeries(key='43OX7U3GKG0BJG8Y',output_format='csv') #CSV
